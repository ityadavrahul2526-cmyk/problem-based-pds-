# %% [markdown]
# Name:Rahul Yadav
# Roll No.:51
# Class: Syit
# Practical:06
# Date:19/08/2026

# %% [markdown]
# 6a. Write a Python program to import a CSV dataset using Pandas and
# display the first 5 and last 5 records.

# %%
import pandas as pd

# %%
df = pd.read_csv("Students.csv")

# %%
print(df.head())
# Out:
#    Roll No    Name Department  Marks  Attendance
# 0       43    Amit     BSc IT     89          56
# 1       45     Raj     BSc CS     76          75
# 2       56   Rahul     BSc IT     92          88
# 3       22  Nitish     BSc CS     84          95
# 4       32   Rohan     BSc IT     65          92

# %% [markdown]
# Print last 5 Students Name

# %%
print(df.tail())
# Out:
#    Roll No    Name Department  Marks  Attendance
# 0       43    Amit     BSc IT     89          56
# 1       45     Raj     BSc CS     76          75
# 2       56   Rahul     BSc IT     92          88
# 3       22  Nitish     BSc CS     84          95
# 4       32   Rohan     BSc IT     65          92

# %%
print(df.shape) #number of rows and columns
# Out:
# (5, 5)

# %%
print(df.columns)
# Out:
# Index(['Roll No', 'Name', 'Department', 'Marks', 'Attendance'], dtype='object')

# %% [markdown]
# 6b. Write a Python program to analyze the dataset by displaying the number of rows and columns, column names, data types, and basic statistical information.

# %%
print(df.dtypes)
# Out:
# Roll No        int64
# Name          object
# Department    object
# Marks          int64
# Attendance     int64
# dtype: object

# %% [markdown]
# 6c. Write a Python program to filter records from the dataset using conditions.

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    Roll No    Name Department  Marks  Attendance
# 0       43    Amit     BSc IT     89          56
# 1       45     Raj     BSc CS     76          75
# 2       56   Rahul     BSc IT     92          88
# 3       22  Nitish     BSc CS     84          95
# 4       32   Rohan     BSc IT     65          92>

# %% [markdown]
# 6d. Write a Python program to sort the dataset based on a selected column
# and display the top 5 records.

# %%
result = df[df["Attendance"]>=90]
print(result)
# Out:
#    Roll No    Name Department  Marks  Attendance
# 3       22  Nitish     BSc CS     84          95
# 4       32   Rohan     BSc IT     65          92

# %% [markdown]
# 6e. Write a Python program to perform data analysis on the dataset by
# finding the maximum, minimum, average, and total values of a numerical
# column.

# %%
print("Maximum Marks ",df["Marks"].max())
print("Minimum Marks ",df["Marks"].min())
# Out:
# Maximum Marks  92
# Minimum Marks  65
